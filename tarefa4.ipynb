# %% [markdown]
# Considere as seguintes EDCC que representam sistemas com os seguintes coeficientes:
#
# b = 0.0053 0.0159 0.0159 0.0053 a = 1.0000
#
# b = 0.0210 0.0632 0.0632 0.0210 a = 1.0000 -1.8663 1.4986 -0.4636
#
# b = 0.1589 0.4029 0.4029 0.1589 a = 1.0000 -0.3082 0.6290 -0.1970
#
# a) plote no mesmo gráfico, a resposta em frequência de cada um desses sistemas.
#
# b) plote no mesmo gráfico, os polos e zeros de cada um desses sistemas.
#
# c) Informe que tipo de filtragem cada um deles realiza
#
# d) Calcule a frequência de corte de cada um deles.

# %%
from numpy import *
from scipy.signal import *
from matplotlib.pyplot import *

# %%
b1 = array([0.0053, 0.0159, 0.0159, 0.0053])
a1 = array([1.0000])

b2 = array([0.0210, 0.0632, 0.0632, 0.0210])
a2 = array([1.0000, -1.8663, 1.4986, -0.4636])

b3 = array([0.1589, 0.4029, 0.4029, 0.1589])
a3 = array([1.0000, -0.3082, 0.6290, -0.1970])

# %%
w1, h1 = freqz(b1, a1)
w2, h2 = freqz(b2, a2)
w3, h3 = freqz(b3, a3)

plot(w1,h1)
plot(w2,h2)
plot(w3,h3)
show()

# %%
20*np.log10(np.abs(h))

plot(w1,20*log10(abs(h1)))
plot(w2,20*log10(abs(h2)))
plot(w3,20*log10(abs(h3)))
show()

# %%
plot(tf2zpk(b1, a1)[0])
plot(tf2zpk(b2, a2)[0])
plot(tf2zpk(b3, a3)[0])
#polos

# %%
plot(tf2zpk(b1, a1)[1])
plot(tf2zpk(b2, a2)[1])
plot(tf2zpk(b3, a3)[1])
from plot_zplane import zplane 
#zeros
