# %%
from numpy import *
from matplotlib.pyplot import *
t = arange(0,1,1/1000)
A = 0.5*sin(250*pi*t)*random.rand(1000)
B = sin(10*pi*t)
C = sin(4*pi*t)
figure(figsize=(16,9))
plot(t,A)
plot(t,B)
plot(t,C)

# %%
D =A+B+C
figure(figsize=(16,9))
plot(t,D)
